# %% [markdown]
# ### OASIS Infobyte Data Science Intern

# %% [markdown]
# ### Topic = Iris Flowers

# %% [markdown]
# ### By = NARESH KUMAR

# %% [markdown]
# ### Dataset Information <br>
#  . Iris dataset contains 6 columns  and 150 rows <br>
#  . Columns : id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species<br>
#  . Species column has 3 classes ( Iris-setosa, Iris-virginica, Iris-versicolor)

# %% [markdown]
# #### Dataset : https://storage.googleapis.com/kaggle-data-sets/4247/6570/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240102%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240102T134624Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...

# %% [markdown]
# ![1_kXYKlCF_wBBm9rIuAlz5Yw.webp](attachment:1_kXYKlCF_wBBm9rIuAlz5Yw.webp)

# %% [markdown]
# ##### Importing Libaries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### Import Iris Dataset

# %%
df=pd.read_csv(r'C:\Users\hp\Desktop\Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# ##### 6 columns and 150 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.drop('Id',axis=1,inplace=True)

# %% [markdown]
# ##### drop id column because id is not necessary

# %%
df.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 8              4.4           2.9            1.4           0.2      Iris-setosa
# 142            5.8           2.7            5.1           1.9   Iris-virginica
# 148            6.2           3.4            5.4           2.3   Iris-virginica
# 56             6.3           3.3            4.7           1.6  Iris-versicolor
# 21             5.1           3.7            1.5           0.4      Iris-setosa

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ##### tno null values in the dataset

# %%
df.duplicated().sum()
# Out:
# 3

# %% [markdown]
# ##### we have 3 duplicates rows in the dataset

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %% [markdown]
# ###  EDA ( Exploratory data analysis)

# %% [markdown]
# #### Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=sns.countplot(x='Species', data=df)
for bars in x.containers:
    x.bar_label(bars)

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df,hue='Species',markers='*')
plt.show()

# %%
plt.figure(figsize=(15, 5))

# Creating the first subplot
plt.subplot(1, 2, 1)
sns.scatterplot(x='SepalLengthCm', y='PetalLengthCm', data=df, hue='Species')

# Creating the second subplot
plt.subplot(1, 2, 2)
sns.scatterplot(x='SepalWidthCm', y='PetalWidthCm', data=df, hue='Species')

plt.show()

# %%
plt.figure(figsize=(15,8))
# Creating the first subplot
plt.subplot(2, 2, 1)
sns.boxplot(x='SepalLengthCm', y='Species', data=df)

# Creating the second subplot
plt.subplot(2, 2, 2)
sns.boxplot(x='SepalWidthCm', y='Species', data=df)

# Creating the third subplot
plt.subplot(2, 2, 3)
sns.boxplot(x='PetalLengthCm', y='Species', data=df)

# Creating the fourth subplot
plt.subplot(2, 2, 4)
sns.boxplot(x='PetalWidthCm', y='Species', data=df)

plt.show()

# %% [markdown]
# ### Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [147 rows x 5 columns]

# %%
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
x=df.drop('Species',axis=1)
y=df.Species

# %% [markdown]
# ### Model Training

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
print("x_train",x_train.shape)
print('x_test',x_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# x_train (102, 4)
# x_test (45, 4)
# y_train (102,)
# y_test (45,)

# %%
from sklearn.metrics import *
def eval_model(model,x_train,y_train,x_test,y_test,model_name):
    model.fit(x_train,y_train)
    ypred=model.predict(x_test)
    train_2=model.score(x_train,y_train)
    test_2=model.score(x_test,y_test)
    MSE=mean_squared_error(y_test,ypred)
    MAE=mean_absolute_error(y_test,ypred)
    RMSE=np.sqrt(MSE)
    res=pd.DataFrame({"Train_2":train_2,'Test_2':test_2,'MSE': MSE,'MAE':MAE,'RMSE':RMSE},index=[model_name])
    return res

# %% [markdown]
# ### Devlop Machine learning model

# %%
from sklearn.linear_model import LogisticRegression

# Assuming lr is your Logistic Regression model
lr = LogisticRegression(max_iter=1000)  # You can adjust the number based on your needs


# Assuming you have the 'eval_model' function defined
# Replace it with your actual evaluation function
Logistic = eval_model(lr, x_train, y_train, x_test, y_test, 'lr')
Logistic
# Out:
#     Train_2  Test_2  MSE  MAE  RMSE
# lr  0.95098     1.0  0.0  0.0   0.0

# %%
from sklearn.neighbors import KNeighborsClassifier
knr=KNeighborsClassifier()
KNeighborsClassifier=eval_model(knr, x_train, y_train, x_test, y_test, 'knr')
KNeighborsClassifier
# Out:
#      Train_2    Test_2       MSE       MAE      RMSE
# knr  0.95098  0.955556  0.044444  0.044444  0.210819

# %%
res=pd.concat([Logistic,KNeighborsClassifier])
res
# Out:
#      Train_2    Test_2       MSE       MAE      RMSE
# lr   0.95098  1.000000  0.000000  0.000000  0.000000
# knr  0.95098  0.955556  0.044444  0.044444  0.210819
